# %%
import json

# %%
dataset_path = r"C:\Users\arnau\Documents\UPF\4t\TFG\ES_pre_corpus_v1.json"

with open(dataset_path, "r", encoding="utf-8") as ds:
    dataset = json.load(ds)

# %%
print(f"Type: {type(dataset)}")
print(f"Length: {len(dataset)}")
# List of 17 dictionaries
# Out:
# Type: <class 'list'>
# Length: 17

# %%
sample = dataset[0]

print(sample.keys())
# Out:
# dict_keys(['meta_data', 'full_original_text', 'full_simplified_text', 'basic_alignments', 'original_sentences', 'simplified_sentences', 'alignments'])

# %%
display(sample["meta_data"])
# Out:
# {'document_id': 'ES_001_005', 'language': 'ES', 'metadata': {'website URL': 'https://www.comunidad.madrid/noticias/2025/01/27/comunidad-madrid-aplica-innovador-programa-ejercicio-terapeutico-pacientes-cancer-hospital-publico-gregorio-maranon', 'Language Identifier': 'ES', 'creation date of text': '2025-01-27T00:00:00', 'characters (without spaces)': 2574, 'Corpus category': 'Informative texts', 'Text Type': 'informative Report', 'Topic': 'Health & Governance', 'Complexity_level_simplification': 'Easy-to-read (A2)', 'Simplification Methodology': 'human', 'copyright okay?': 'Y', 'Coded translator name': 'translator_1', 'institution in charge': 'PIM', 'Tested by a test group (Y/N)': 'N'}}

# %%
print(len(sample["full_original_text"]))
print(len(sample["full_simplified_text"]))
print(sample["full_simplified_text"])
# Out:
# 3020
# 2966
# La Comunidad de Madrid pone en marcha un programa de terapias
#
# con ejercicio físico para pacientes con cáncer.
#
# El Hospital público Gregorio Marañón de Madrid
#
# lleva a cabo este programa novedoso.
#
# Fátima Matute es la consejera de Sanidad.
#
# La consejera visitó el hospital donde realizan este programa.
#
# Un equipo de profesionales y médicos de distintas especialidades
#
# atienden a los pacientes.
#
# Los médicos son:
#
# fisioterapeutas
#
# rehabilitadores
#
# terapeutas ocupacionales
#
# logopedas
#
# El programa funciona desde febrero del año 2024.
#
# El programa tiene entrenamientos de ejercicios físicos de fuerza y de resistencia.
#
# El equipo de profesionales adapta cada entrenamiento
#
# a las necesidades de cada paciente.
#
# Antes de comenzar el tratamiento,
#
# un rehabilitador y un fisioterapeuta evalúa el estado físico general del paciente.
#
# También evalúan el estado de sus huesos y músculos, su sistema nervioso,
#
# su sistema respiratorio y el tiempo que aguanta haciendo ejercicio.
#
# De esta forma, el equipo de profesionales diseña actividades de ejercicio físico
#
# para cada paciente.
#
# Los pacientes realizan estas actividades durante 8 semanas
#
# y el equipo de profesionales vigila el estado de los pacientes.
#
# El programa evaluó a 180 pacientes
#
# y casi todos terminaron o comenzaron la terapia.
#
# Los pacientes se recuperaron de forma física y emocional.
#
# Los pacientes son enfermos que recibieron tratamientos
#
# para el cáncer de mama o de útero.
#
# Pero los pacientes pueden entrar a este programa
#
# incluso cuando están recibiendo tratamiento para el cáncer
#
# como quimioterapia o después de una operación.
#
# El Hospital Gregorio Marañón ofrece este programa
#
# en el nuevo edificio de Oncología y Terapias Avanzadas.
#
# El edificio tiene un gimnasio y otras zonas con equipos
#
# para poder realizar este programa.
#
# Además, el Servicio de Rehabilitación y el de Cirugía General
#
# realizan otro pograma de preparación y rehabilitación
#
# para pacientes con cáncer de esófago.
#
# El objetivo de este programa es preparar a los pacientes
#
# para la cirugía y la fase de recuperación de después.
#
# Otros programas especializados para distintos tipos de cáncer
#
# El Hospital Gregorio Marañón también tiene programas
#
# para enfermos de cáncer de cabeza y cuello.
#
# Este programa ayuda a recuperarse a pacientes
#
# que no pueden tragar, hablar o que perdieron la voz
#
# por tumores en el cerebro.
#
# En el año 2025, el Hospital comienza otro proyecto
#
# de terapia para pacientes que operaron en el cerebro
#
# o pacientes que tienen problemas cerebrales
#
# por tratamientos contra el cáncer.
#
# Estos programas de equipos de profesionales de varias áreas
#
# ayudan a mejorar los problemas físicos y cerebrales
#
# de los pacientes que necesitan apoyo para recuperarse.
#
# El Hospital Gregorio Marañón se ha convertido en un ejemplo en España
#
# porque pone en marcha programas novedosos
#
# con equipos de profesionales de distintas áreas.
#
# Estos programas atienden las necesidades de los pacientes
#
# y mejorar su calidad de vida.

# %%
display(sample["basic_alignments"])

for alignment in sample["basic_alignments"][0]:
    print(alignment)
# Out:
# [{'original_sentence': 'La Comunidad de Madrid aplica un innovador programa de ejercicio terapéutico para pacientes con cáncer en el Hospital público Gregorio Marañón.\nLa Comunidad de Madrid aplica un innovador programa de ejercicios terapéuticos para pacientes con cáncer en el Hospital público General Universitario Gregorio Marañón.', 'easy_to_read_sentence': 'La Comunidad de Madrid pone en marcha un programa de terapias\ncon ejercicio físico para pacientes con cáncer.\nEl Hospital público Gregorio Marañón de Madrid\nlleva a cabo este programa novedoso.', 'annotation_criteria': ['5 Uso de verbo frecuente', '12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.', '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', '14 Eliminación de polisemia o agregación con contexto.', '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', '5 Uso de verbo frecuente', '12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.', '9 Uso de adjetivo de uso frecuente.'], 'complex_part': 'Aplicar: verbo complejo y abstracto. Oración muy larga.\nEjercicio: Palabra polisémica.\nInnovador: adjetivo complejo, se cambia por novedoso. '}, {'original_sentence': 'La consejera de Sanidad, Fátima Matute, ha visitado hoy sus instalaciones, donde los enfermos son atendidos por un equipo multidisciplinar de médicos rehabilitadores, fisioterapeutas, terapeutas ocupacionales y logopedas.', 'easy_to_read_sentence': 'Fátima Matute es la consejera de Sanidad.\nLa consejera visitó el hospital donde realizan este programa.\nUn equipo de profesionales y médicos de distintas especialidades\natienden a los pacientes.\nLos médicos son:\nfisioterapeutas\nrehabilitadores\nterapeutas ocupacionales\nlogopedas', 'annotation_criteria': ['2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', '30 Eliminación de incisos y aposiciones.', '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', '19 Uso de modo indicativo y de tiempos verbales sencillos (presente de indicativo, futuro simple y pretérito perfecto simple y pretérito imperfecto). ', '20 Eliminación de tiempos compuestos.', '12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.', '24 Eliminación de oraciones impersonales', '11 Uso de sustantivo cortos, sencillos y de uso habitual. ', '24 Eliminación de oraciones impersonales', '34 Uso de formato de listado', '4 Uso de dos puntos (:) para introducir listas.', '34 Uso de formato de listado', '34 Uso de formato de listado', '34 Uso de formato de listado', '34 Uso de formato de listado'], 'complex_part': 'Fátima Matute: inciso o aposición. Oración larga.\nHa visitado: verbo en tiempo compuesto. \nMultidisciplinar: Palabra técnica y larga. Oración en voz pasiva se cambia a activa.\nOración en voz pasiva se cambia a activa.'}, {'original_sentence': 'La iniciativa, que funciona desde febrero del año pasado, está diseñada de manera personalizada y combina entrenamientos de fuerza con otros de carácter aeróbico adaptados a las necesidades específicas de cada persona.', 'easy_to_read_sentence': 'El programa funciona desde febrero del año 2024.\nEl programa tiene entrenamientos de ejercicios físicos de fuerza y de resistencia.\nEl equipo de profesionales adapta cada entrenamiento\na las necesidades de cada paciente.', 'annotation_criteria': ['2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', '30 Eliminación de incisos y aposiciones.', '12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.', '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', '19 Uso de modo indicati ...
# original_sentence
# easy_to_read_sentence
# annotation_criteria
# complex_part

# %%
print(len(sample["original_sentences"]))
print(display(sample["original_sentences"]))
print(len(sample["simplified_sentences"]))
print(display(sample["simplified_sentences"]))
# Out:
# 15
# [{'id': 0, 'text': 'La Comunidad de Madrid aplica un innovador programa de ejercicio terapéutico para pacientes con cáncer en el Hospital público Gregorio Marañón.\nLa Comunidad de Madrid aplica un innovador programa de ejercicios terapéuticos para pacientes con cáncer en el Hospital público General Universitario Gregorio Marañón.'}, {'id': 1, 'text': 'La consejera de Sanidad, Fátima Matute, ha visitado hoy sus instalaciones, donde los enfermos son atendidos por un equipo multidisciplinar de médicos rehabilitadores, fisioterapeutas, terapeutas ocupacionales y logopedas.'}, {'id': 2, 'text': 'La iniciativa, que funciona desde febrero del año pasado, está diseñada de manera personalizada y combina entrenamientos de fuerza con otros de carácter aeróbico adaptados a las necesidades específicas de cada persona.'}, {'id': 3, 'text': 'Cuenta con una evaluación integral y un seguimiento por parte de un rehabilitador y un fisioterapeuta para valorar su estado físico general, osteomuscular, neurológico, respiratorio y la tolerancia al ejercicio.'}, {'id': 4, 'text': 'Con ello se diseña su tabla de actividades específicas, que se lleva a cabo en un programa de ocho semanas, siempre monitorizado por profesionales del hospital.'}, {'id': 5, 'text': 'Hasta ahora se ha evaluado a 180 personas, de las que 120 ya han realizado el programa o están inmersos en el proceso, logrando una significativa recuperación funcional y emocional.'}, {'id': 6, 'text': 'Fundamentalmente lo integran enfermos con secuelas derivadas de tratamientos oncológicos como cáncer de mama y ginecológicos.'}, {'id': 7, 'text': 'No obstante, se puede adaptar a cualquier fase, incluso en proceso activo de quimioterapia o postquirúrgico.'}, {'id': 8, 'text': 'El Hospital público Gregorio Marañón ofrece esta actividad en su nuevo edificio de Oncología y Terapias Avanzadas, con un gimnasio y áreas especialmente diseñadas y equipadas para ello.'}, {'id': 9, 'text': 'Además, su Servicio de Rehabilitación, en colaboración con el de Cirugía General, está implementando otro revolucionario programa de pre-habilitación y rehabilitación para pacientes con cáncer de esófago.'}, {'id': 10, 'text': 'Su objetivo es su preparación funcional antes de la cirugía y su mejora postoperatoria.'}, {'id': 11, 'text': 'Intervenciones especializadas para distintos tipos de cáncer\xa0\nEn esta línea de avances, también se han diseñado intervenciones especializadas para enfermos con cáncer de cabeza y cuello, como el restablecimiento de disfagias, disglosias y disfonías a través de la foniatría y logopedia, así como el abordaje de secuelas en el lenguaje de pacientes con tumores cerebrales.'}, {'id': 12, 'text': 'También en 2025 se iniciará otro proyecto de terapia cognitiva\xa0online\xa0para enfermos de neurocirugía y aquellos con alteraciones derivadas de tratamientos oncológicos.'}, {'id': 13, 'text': 'Estas estrategias multidisciplinarias permiten abordar de forma integral las secuelas físicas y cognitivas, garantizando una recuperación adaptada a las necesidades de cada persona.'}, {'id': 14, 'text': 'De esta manera, el Hospital público Gregorio Marañón se posiciona como un referente nacional, liderando un enfoque innovador y multidisciplinario que acompaña a los pacientes y mejorando su calidad de vida con una atención centrada en sus necesidades específicas.'}]
# None
# 60
# [{'id': 0, 'text': 'La Comunidad de Madrid pone en marcha un programa de terapias', 'annotation_criteria': '5 Uso de verbo frecuente  -  12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.  -  2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', 'complex_part': 'Aplicar: verbo complejo y abstracto. Oración muy larga.'}, {'id': 1, 'text': 'con ejercicio físico para pacientes con cáncer.', 'annotation_criteria': '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.  -  14 Eliminación de polisemia o agregación con contexto.', 'complex_part': 'Ejercicio: Palabra polisémica.'}, {'id': 2, 'text': 'El Hospital público Gregorio Marañón de Madrid', 'annotation_criteria': '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', 'complex_part': ''}, {'id': 3, 'text': 'lleva a cabo este programa novedoso.', 'annotation_criteria': '5 Uso de verbo frecuente  -  12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.  -  9 Uso de adjetivo de uso frecuente.', 'complex_part': 'Innovador: adjetivo complejo, se cambia por novedoso. '}, {'id': 4, 'text': 'Fátima Matute es la consejera de Sanidad.', 'annotation_criteria': '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.  -  30 Eliminación de incisos y aposiciones.', 'complex_part': 'Fátima Matute: inciso o aposición. Oración larga.'}, {'id': 5, 'text': 'La consejera visitó el hospital donde realizan este programa.', 'annotation_criteria': '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.  -  19 Uso de modo indicativo y de tiempos verbales sencillos (presente de indicativo, futuro simple y pretérito perfecto simple y pretérito imperfecto).   -  20 Eliminación de tiempos compuestos.', 'complex_part': 'Ha visitado: verbo en tiempo compuesto. '}, {'id': 6, 'text': 'Un equipo de profesionales y médicos de distintas especialidades', 'annotation_criteria': '12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.  -  24 Eliminación de oraciones impersonales  -  11 Uso de sustantivo cortos, sencillos y de uso habitual. ', 'complex_part': 'Multidisciplinar: Palabra técnica y larga. Oración en voz pasiva se cambia a activa.'}, {'id': 7, 'text': 'atienden a los pacientes.', 'annotation_criteria': '24 Eliminación de oraciones impersonales', 'complex_part': 'Oración en voz pasiva se cambia a activa.'}, {'id': 8, 'text': 'Los médicos son:', 'annotation_criteria': '34 Uso de formato de listado  -  4 Uso de dos puntos (:) para introducir listas.', 'complex_part': ''}, {'id': 9, 'text': 'fisioterapeutas', 'annotation_criteria': '34 Uso de formato de listado', 'complex_part': ''}, {'id': 10, 'text': 'rehabilitadores', 'annotation_criteria': '34 Uso de formato de listado', 'complex_part': ''}, {'id': 11, 'text': 'terapeutas ocupacionales', 'annotation_criteria': '34 Uso de formato de listado', 'complex_part': ''}, {'id': 12, 'text': 'logopedas', 'annotation_criteria': '34 Uso de formato de listado', 'complex_part': ''}, {'id': 13, 'text': 'El programa funciona desde febrero del año 2024.', 'annotation_criteria': '2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.  -  30 Eliminación de incisos y aposiciones.', 'complex_part': 'Oración larga con incisos.'}, {'id': 14, 'text': 'El programa tiene entrenamientos de ejercicios físicos de fuerza y de resistencia.', 'annotation_criteria': '12 Eliminación o cambio de términos abstractos, extranjerismos, palabra de contenido indeterminado y/o tecnicismos.  -  2 Uso de punto y aparte o salto de línea para separar frases con ideas diferentes.', 'complex_part': 'Entrenamientos de fuerza y aeróbicos: términos complejos técnicos.'}, {'id': 15, 'text': 'El equipo de profesionales adapta cada entrenamiento', 'annot ...
# None

# %%
print("OG")
for og in sample["original_sentences"]:
    print(og["text"])

print("\nSim")
for sim in sample["simplified_sentences"]:
    print(sim["text"])
# Out:
# OG
# La Comunidad de Madrid aplica un innovador programa de ejercicio terapéutico para pacientes con cáncer en el Hospital público Gregorio Marañón.
# La Comunidad de Madrid aplica un innovador programa de ejercicios terapéuticos para pacientes con cáncer en el Hospital público General Universitario Gregorio Marañón.
# La consejera de Sanidad, Fátima Matute, ha visitado hoy sus instalaciones, donde los enfermos son atendidos por un equipo multidisciplinar de médicos rehabilitadores, fisioterapeutas, terapeutas ocupacionales y logopedas.
# La iniciativa, que funciona desde febrero del año pasado, está diseñada de manera personalizada y combina entrenamientos de fuerza con otros de carácter aeróbico adaptados a las necesidades específicas de cada persona.
# Cuenta con una evaluación integral y un seguimiento por parte de un rehabilitador y un fisioterapeuta para valorar su estado físico general, osteomuscular, neurológico, respiratorio y la tolerancia al ejercicio.
# Con ello se diseña su tabla de actividades específicas, que se lleva a cabo en un programa de ocho semanas, siempre monitorizado por profesionales del hospital.
# Hasta ahora se ha evaluado a 180 personas, de las que 120 ya han realizado el programa o están inmersos en el proceso, logrando una significativa recuperación funcional y emocional.
# Fundamentalmente lo integran enfermos con secuelas derivadas de tratamientos oncológicos como cáncer de mama y ginecológicos.
# No obstante, se puede adaptar a cualquier fase, incluso en proceso activo de quimioterapia o postquirúrgico.
# El Hospital público Gregorio Marañón ofrece esta actividad en su nuevo edificio de Oncología y Terapias Avanzadas, con un gimnasio y áreas especialmente diseñadas y equipadas para ello.
# Además, su Servicio de Rehabilitación, en colaboración con el de Cirugía General, está implementando otro revolucionario programa de pre-habilitación y rehabilitación para pacientes con cáncer de esófago.
# Su objetivo es su preparación funcional antes de la cirugía y su mejora postoperatoria.
# Intervenciones especializadas para distintos tipos de cáncer
# En esta línea de avances, también se han diseñado intervenciones especializadas para enfermos con cáncer de cabeza y cuello, como el restablecimiento de disfagias, disglosias y disfonías a través de la foniatría y logopedia, así como el abordaje de secuelas en el lenguaje de pacientes con tumores cerebrales.
# También en 2025 se iniciará otro proyecto de terapia cognitiva online para enfermos de neurocirugía y aquellos con alteraciones derivadas de tratamientos oncológicos.
# Estas estrategias multidisciplinarias permiten abordar de forma integral las secuelas físicas y cognitivas, garantizando una recuperación adaptada a las necesidades de cada persona.
# De esta manera, el Hospital público Gregorio Marañón se posiciona como un referente nacional, liderando un enfoque innovador y multidisciplinario que acompaña a los pacientes y mejorando su calidad de vida con una atención centrada en sus necesidades específicas.
#
# Sim
# La Comunidad de Madrid pone en marcha un programa de terapias
# con ejercicio físico para pacientes con cáncer.
# El Hospital público Gregorio Marañón de Madrid
# lleva a cabo este programa novedoso.
# Fátima Matute es la consejera de Sanidad.
# La consejera visitó el hospital donde realizan este programa.
# Un equipo de profesionales y médicos de distintas especialidades
# atienden a los pacientes.
# Los médicos son:
# fisioterapeutas
# rehabilitadores
# terapeutas ocupacionales
# logopedas
# El programa funciona desde febrero del año 2024.
# El programa tiene entrenamientos de ejercicios físicos de fuerza y de resistencia.
# El equipo de profesionales adapta cada entrenamiento
# a las necesidades de cada paciente.
# Antes de comenzar el tratamiento,
# un rehabilitador y un fisioterapeuta evalúa el estado físico general del paciente.
# También evalúan el estado de sus huesos y músculos, su sistema nervioso,
# su sistema respiratorio y el tiempo que aguanta haciendo ejercicio.
# De esta forma, el equipo de profesionales diseña actividades de ejercicio físico
# para cada paciente.
# Los pacientes realizan estas actividades durante 8 semanas
# y el equipo de profesionales vigila el estado de los pacientes.
# El programa evaluó a 180 pacientes
# y casi todos terminaron o comenzaron la terapia.
# Los pacientes se recuperaron de forma física y emocional.
# Los pacientes son enfermos que recibieron tratamientos
# para el cáncer de mama o de útero.
# Pero los pacientes pueden entrar a este programa
# incluso cuando están recibiendo tratamiento para el cáncer
# como quimioterapia o después de una operación.
# El Hospital Gregorio Marañón ofrece este programa
# en el nuevo edificio de Oncología y Terapias Avanzadas.
# El edificio tiene un gimnasio y otras zonas con equipos
# para poder realizar este programa.
# Además, el Servicio de Rehabilitación y el de Cirugía General
# realizan otro pograma de preparación y rehabilitación
# para pacientes con cáncer de esófago.
# El objetivo de este programa es preparar a los pacientes
# para la cirugía y la fase de recuperación de después.
# Otros programas especializados para distintos tipos de cáncer
# El Hospital Gregorio Marañón también tiene programas
# para enfermos de cáncer de cabeza y cuello.
# Este programa ayuda a recuperarse a pacientes
# que no pueden tragar, hablar o que perdieron la voz
# por tumores en el cerebro.
# En el año 2025, el Hospital comienza otro proyecto
# de terapia para pacientes que operaron en el cerebro
# o pacientes que tienen problemas cerebrales
# por tratamientos contra el cáncer.
# Estos programas de equipos de profesionales de varias áreas
# ayudan a mejorar los problemas físicos y cerebrales
# de los pacientes que necesitan apoyo para recuperarse.
# El Hospital Gregorio Marañón se ha convertido en un ejemplo en España
# porque pone en marcha programas novedosos
# con equipos de profesionales de distintas áreas.
# Estos programas atienden las necesidades de los pacientes
# y mejorar su calidad de vida.

# %%
for alignment in sample["alignments"][0]:
    print(alignment)

print(sample["alignments"][6]["original_sentence_id"])
print(sample["alignments"][6]["simplified_sentence_id"])
print(sample["alignments"][6]["position_in_sequence"])
print(sample["alignments"][6]["total_simplified_sentences"])
# Out:
# original_sentence_id
# simplified_sentence_id
# position_in_sequence
# total_simplified_sentences
# 1
# 6
# 3
# 9
